# %%
# FFT
import cmath
import numpy as np



m = 3
a = [9, 7, 5, 3, 1, 4, 6, 8]
N = 2**m


a_0 = [a[i] for i in range(0, len(a))]
S = N



def tran(a):
    n = len(a)
    num_bits = n.bit_length() - 1
    result = [0] * n
    for i in range(n):
        binary_str = bin(i)[2:].zfill(num_bits)
        rev_i = int(binary_str[::-1], 2)
        result[rev_i] = a[i]
    return result



def FFT(a,m):
    N = 2**m
    a_0 = a.copy()
    S = N

    while S > 1:
        T = N//S
        for k in range(1, T+1):
            for l in range((k-1)*S, (k-1)*S+S//2 ):
                y = a_0[l]
                a_0[l] = y + a_0[l+S//2]
                a_0[l+S//2] = (y - a_0[l+S//2])*cmath.exp(-2j*cmath.pi*l/S)
        S = S//2

    return tran(a_0)


result = FFT(a, m)
correct_result = np.fft.fft(a)

print(result)
# Out:
# [43, (13.65685424949238+2.414213562373095j), (-1+0j), (2.3431457505076194+0.4142135623730947j), (-1+0j), (2.3431457505076203-0.41421356237309376j), (-1-2.4492935982947064e-16j), (13.656854249492381-2.4142135623730803j)]
# hahahahahaha
# [43.        +0.j         13.65685425+2.41421356j -1.        +0.j
#   2.34314575+0.41421356j -1.        +0.j          2.34314575-0.41421356j
#  -1.        +0.j         13.65685425-2.41421356j]

# %%
# FT
import cmath
import numpy as np


def DFT(a):
    N = len(a)
    W = gen_W(N)
    a_0 = np.dot(W,a)
    return a_0


def gen_W(N):
    w = cmath.exp(-2j*cmath.pi/N)
    W = np.zeros((N, N), dtype=complex)
    for j in range(N):
        for k in range(N):
            # 计算 W 矩阵的每个元素
            W[j, k] = w ** (j*k)

    return W


a = [9, 7, 5, 3, 1, 4, 6, 8]

print(DFT(a))
# Out:
# [43.        +0.00000000e+00j 13.65685425+2.41421356e+00j
#  -1.        +8.88178420e-15j  2.34314575+4.14213562e-01j
#  -1.        +0.00000000e+00j  2.34314575-4.14213562e-01j
#  -1.        -2.66453526e-14j 13.65685425-2.41421356e+00j]

# %%
# Compare
import time
import numpy as np
import cmath
# 定义随机数范围
a = -100
b = 100
m = 15
# 计算序列长度
length = 2**m

# 生成指定范围的随机实部和虚部
real_part = a + (b - a) * np.random.rand(length)
imag_part = a + (b - a) * np.random.rand(length)

# 组合实部和虚部形成复数序列
complex_sequence = real_part + 1j * imag_part
a = complex_sequence

# 测量 FFT 函数的运行时间
start_time_fft = time.time()
FFT_result = FFT(a, m)
end_time_fft = time.time()
fft_execution_time = end_time_fft - start_time_fft

# 测量 DFT 函数的运行时间
start_time_dft = time.time()
DFT_result = DFT(a)
end_time_dft = time.time()
dft_execution_time = end_time_dft - start_time_dft

print("FFT result:", FFT_result)
print("DFT result:", DFT_result)
print(f"FFT 函数运行时间: {fft_execution_time} 秒")
print(f"DFT 函数运行时间: {dft_execution_time} 秒")
# Out:
# FFT result: [(12860.073428327643+7357.195183440882j), (7501.412893855459+5991.896018157744j), (6956.336808058779-22271.92423047359j), (-12759.796750144313+13379.643939800855j), (11857.471415644544+19262.973074290436j), (4553.917578278507-1244.9038607752318j), (-7871.577507748194+3814.1262134231583j), (-4628.924477330058-18922.011993710003j), (13662.585557608258+10316.05371505816j), (2842.855890946258-1055.3445443619394j), (9131.839991234527+2608.8958588063997j), (-11498.94148295428-8720.035740155814j), (3718.1976328935457-13295.120459087317j), (578.6778675056348+3063.290032824507j), (1843.3628508756956+8816.225735162541